# %%
import pandas as pd

employees = pd.read_csv("../data/employees.csv")
departments = pd.read_csv("../data/departments.csv")
performance = pd.read_csv("../data/performance.csv")
attendance = pd.read_csv("../data/attendance.csv")
sales = pd.read_csv("../data/sales.csv")

employees.head()
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   employee_id    20 non-null     object
#  1   employee_name  20 non-null     object
#  2   department_id  20 non-null     int64
#  3   job_title      20 non-null     object
#  4   hire_date      20 non-null     object
#  5   salary         20 non-null     int64
# dtypes: int64(2), object(4)
# memory usage: 1.1+ KB
